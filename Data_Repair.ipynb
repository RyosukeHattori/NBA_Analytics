# %%
import pandas as pd

# %%
df = pd.read_csv("./CSS/championsdata.csv")

# %%
df2 = pd.read_csv("./CSS/runnerupsdata.csv")

# %%
df.head()
# Out:
#    Year    Team  Game  Win  Home   MP  FG  FGA    FGP  TP ...     FTP  ORB  \
# 0  1980  Lakers     1    1     1  240  48   89  0.539   0 ...   0.867   12
# 1  1980  Lakers     2    0     1  240  48   95  0.505   0 ...   0.667   15
# 2  1980  Lakers     3    1     0  240  44   92  0.478   0 ...   0.767   22
# 3  1980  Lakers     4    0     0  240  44   93  0.473   0 ...   0.737   18
# 4  1980  Lakers     5    1     1  240  41   91  0.451   0 ...   0.788   19
#
#    DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 0   31   43   30    5    9   17  24  109
# 1   37   52   32   12    7   26  27  104
# 2   34   56   20    5    5   20  25  111
# 3   31   49   23   12    6   19  22  102
# 4   37   56   28    7    6   21  27  108
#
# [5 rows x 24 columns]

# %%
df
# Out:
#      Year       Team  Game  Win  Home   MP  FG  FGA    FGP  TP ...     FTP  \
# 0    1980     Lakers     1    1     1  240  48   89  0.539   0 ...   0.867
# 1    1980     Lakers     2    0     1  240  48   95  0.505   0 ...   0.667
# 2    1980     Lakers     3    1     0  240  44   92  0.478   0 ...   0.767
# 3    1980     Lakers     4    0     0  240  44   93  0.473   0 ...   0.737
# 4    1980     Lakers     5    1     1  240  41   91  0.451   0 ...   0.788
# 5    1980     Lakers     6    1     0  240  45   92  0.489   0 ...   0.943
# 6    1981    Celtics     1    1     1  240  41   95  0.432   0 ...   0.800
# 7    1981    Celtics     2    0     1  240  41   82  0.500   0 ...   0.615
# 8    1981    Celtics     3    1     0  240  40   89  0.449   2 ...   0.632
# 9    1981    Celtics     4    0     0  240  35   74  0.473   0 ...   0.667
# 10   1981    Celtics     5    1     1  240  41   94  0.436   0 ...   0.771
# ...

# %%
df2
# Out:
#      Year       Team  Game  Win  Home   MP  FG  FGA    FGP  TP ...     FTP  \
# 0    1980     Sixers     1    0     0  240  40   90  0.444   0 ...   0.786
# 1    1980     Sixers     2    1     0  240  43   85  0.506   0 ...   0.778
# 2    1980     Sixers     3    0     1  240  45   93  0.484   1 ...   0.588
# 3    1980     Sixers     4    1     1  240  41   79  0.519   0 ...   0.885
# 4    1980     Sixers     5    0     0  240  42   94  0.447   0 ...   0.792
# 5    1980     Sixers     6    0     1  240  47   89  0.528   0 ...   0.591
# 6    1981    Rockets     1    0     0  240  42   99  0.424   0 ...   0.786
# 7    1981    Rockets     2    1     0  240  34   85  0.400   2 ...   0.688
# 8    1981    Rockets     3    0     1  240  24   79  0.304   0 ...   0.742
# 9    1981    Rockets     4    1     1  240  37  103  0.359   1 ...   0.727
# 10   1981    Rockets     5    0     0  240  30   84  0.357   0 ...   0.606
# ...

# %%
list(df)
# Out:
# ['Year',
#  'Team',
#  'Game',
#  'Win',
#  'Home',
#  'MP',
#  'FG',
#  'FGA',
#  'FGP',
#  'TP',
#  'TPA',
#  'TPP',
#  'FT',
#  'FTA',
#  'FTP',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS']

# %%
df_current=df.query('Year >= 2015')

# %%
df_current
# Out:
#      Year       Team  Game  Win  Home   MP  FG  FGA    FGP  TP ...     FTP  \
# 198  2015   Warriors     1    1     1  265  39   88  0.443  10 ...   0.909
# 199  2015   Warriors     2    0     1  265  33   83  0.398   8 ...   0.760
# 200  2015   Warriors     3    0     0  240  36   90  0.400  12 ...   0.583
# 201  2015   Warriors     4    1     0  240  36   77  0.468  12 ...   0.704
# 202  2015   Warriors     5    1     1  240  36   75  0.480  12 ...   0.588
# 203  2015   Warriors     6    1     0  240  37   85  0.435  13 ...   0.621
# 204  2016  Cavaliers     1    0     0  240  32   84  0.381   7 ...   0.900
# 205  2016  Cavaliers     2    0     0  240  28   79  0.354   5 ...   0.667
# 206  2016  Cavaliers     3    1     1  240  48   91  0.527  12 ...   0.706
# 207  2016  Cavaliers     4    0     1  240  38   81  0.469   6 ...   0.577
# 208  2016  Cavaliers     5    1     0  240  44   83  0.530  10 ...   0.609
# ...

# %%
s = len(df_current)

# %%
list(df_current)
# Out:
# ['Year',
#  'Team',
#  'Game',
#  'Win',
#  'Home',
#  'MP',
#  'FG',
#  'FGA',
#  'FGP',
#  'TP',
#  'TPA',
#  'TPP',
#  'FT',
#  'FTA',
#  'FTP',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS']

# %%
df_repair= df_current.loc[:,['Year','Team','Game','Win','Home','FGA','FGP','FTA','FTP','ORB','AST','STL','BLK','TOV','PTS']]

# %%
df_repair
# Out:
#      Year       Team  Game  Win  Home  FGA    FGP  FTA    FTP  ORB  AST  STL  \
# 198  2015   Warriors     1    1     1   88  0.443   22  0.909   11   24    8
# 199  2015   Warriors     2    0     1   83  0.398   25  0.760   10   16   11
# 200  2015   Warriors     3    0     0   90  0.400   12  0.583   18   21    6
# 201  2015   Warriors     4    1     0   77  0.468   27  0.704    6   24    5
# 202  2015   Warriors     5    1     1   75  0.480   34  0.588   11   25    7
# 203  2015   Warriors     6    1     0   85  0.435   29  0.621    7   28   11
# 204  2016  Cavaliers     1    0     0   84  0.381   20  0.900   15   17    7
# 205  2016  Cavaliers     2    0     0   79  0.354   24  0.667    9   15   15
# 206  2016  Cavaliers     3    1     1   91  0.527   17  0.706   17   23    8
# 207  2016  Cavaliers     4    0     1   81  0.469   26  0.577   16   15    5
# 208  2016  Cavaliers     5    1     0   83  0.530   23  0.609    8   15   11
# ...

# %%
df2_current=df2.query('Year >= 2015')

# %%
df2_repair= df2_current.loc[:,['Year','Team','Game','Win','Home','FGA','FGP','FTA','FTP','ORB','AST','STL','BLK','TOV','PTS']]

# %%
mean = (df_repair.query('Year == 2015').mean())

# %%
mean
# Out:
# Year    2015.000000
# Game       3.500000
# Win        0.666667
# Home       0.500000
# FGA       83.000000
# FGP        0.437333
# FTA       24.833333
# FTP        0.694167
# ORB       10.500000
# AST       23.000000
# STL        8.000000
# BLK        5.000000
# TOV       12.666667
# PTS      100.666667
# dtype: float64

# %% [markdown]
# type(mean)

# %%
type(mean)
# Out:
# pandas.core.series.Series

# %%
mean.head()
# Out:
# Year    2015.000000
# Game       3.500000
# Win        0.666667
# Home       0.500000
# FGA       83.000000
# dtype: float64

# %%
mean.T
# Out:
# Year    2015.000000
# Game       3.500000
# Win        0.666667
# Home       0.500000
# FGA       83.000000
# FGP        0.437333
# FTA       24.833333
# FTP        0.694167
# ORB       10.500000
# AST       23.000000
# STL        8.000000
# BLK        5.000000
# TOV       12.666667
# PTS      100.666667
# dtype: float64

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
